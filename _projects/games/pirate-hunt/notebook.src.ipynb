# %% [markdown]
# ---
# layout: post
# title: Open Coding Society - Pirate Mega Game, Do you dare to play?
# description: Start interactive experience by pressing "Play".
# permalink: /pirate-hunt
# codemirror: true
# hide: true
# toc: false
# ---

# %%
# %%js
#
# // GAME_RUNNER: Play Crater Falls and test gravity, jumps, and platform collisions. Use WASD or arrow keys to move and jump. | hide_edit: true, width: 100%, height: 500px
#
# import { GameControl } from '/assets/js/GameEnginev1.1/essentials/Imports.js';
# import newlevel from '/assets/js/projects/pirate-hunt/levels/new-level.js';
#
# export const gameLevelClasses = [newlevel];
# export { GameControl };
